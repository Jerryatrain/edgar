# %%
import pandas as pd
import numpy as np
import json
from edgar import *
from tqdm import tqdm
from joblib import Parallel, delayed
import pickle
import re
import multiprocessing
set_identity('kikijkojiojqq.com@gmail.com')
# Out:
# [15:21:41] INFO     Identity of the Edgar REST client set to [kikijkojiojqq.com@gmail.com]              ]8;id=529609;file:///opt/anaconda3/envs/learn/lib/python3.9/site-packages/edgar/core.py\core.py]8;;\:]8;id=130120;file:///opt/anaconda3/envs/learn/lib/python3.9/site-packages/edgar/core.py#158\158]8;;\

# %%
def get_section(filing):
    file_info = filing.to_dict()

    # add url
    file_info['url'] = filing.document.url

    # add sections
    file_info['sections'] = filing.sections()

    return file_info

# %%
year = 2023
# get 10-K and 10-Q filings for 2024

filings = get_filings(year=year, form=['10-K', '10-Q' ,'DEF 14A'])
print(f' Runing {year}')

#res = Parallel(n_jobs=-1)(delayed(get_section)(filing) for filing in tqdm(filings))
res = []
for filing in tqdm(filings):
    res.append(get_section(filing))

file_collection = dict(res)

# save the collection
with open(f'soft_check/file_collection_{year}_loop.pkl', 'wb') as f:
    pickle.dump(file_collection, f)
# Out:
#  Runing 2023
#   6%|▌         | 1947/34164 [28:53<7:58:08,  1.12it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 10
#       8 res = []
#       9 for filing in tqdm(filings):
# ---> 10     res.append(get_section(filing))
#      12 file_collection = dict(res)
#      14 # save the collection
#
# Cell In[2], line 8, in get_section(filing)
#       5 file_info['url'] = filing.document.url
#       7 # add sections
# ----> 8 file_info['sections'] = filing.sections()
#      10 return file_info
#
# File /opt/anaconda3/envs/learn/lib/python3.9/site-packages/edgar/_filings.py:1237, in Filing.sections(self)
#    1235 @lru_cache(maxsize=1)
#    1236 def sections(self) -> List[str]:
# -> 1237     html = self.html()
#    1238     assert html is not None
#    1239     return html_sections(html)
#
# ...
